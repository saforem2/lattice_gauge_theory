# %% [markdown]
# # Lattice Gauge Theory Simulations

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

from lattice_gauge_theory.utils import *
from lattice_gauge_theory.field import *
from lattice_gauge_theory.lattice import Lattice

# %matplotlib notebook

import matplotlib as mpl
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 

#plt.style.use('dark_background')

# %%
help(pickle.dump)

# %% [markdown]
# ## $\mathbb{Z}_2$ in $4D$

# %%
dim = 4 # 4 Dimensions
N = 2 # Z_N
lattice_size = 8 
# instantiate gauge field
field = Field((lattice_size,)*dim, *ZN(N, 'delta'), 0, init='rand')

# %%
energy_24, std_24, betas_24 = hysteresis(field,(0,3,.01*dim),neq=5,nstat=60//dim,relax=20//dim,inc=1)
# Out:
# Step 0 of 150
# Step 1 of 150
# Step 2 of 150
# Step 3 of 150
# Step 4 of 150
# Step 5 of 150
# Step 6 of 150
# Step 7 of 150
# Step 8 of 150
# Step 9 of 150
# Step 10 of 150
# Step 11 of 150
# Step 12 of 150
# Step 13 of 150
# Step 14 of 150
# Step 15 of 150
# Step 16 of 150
# Step 17 of 150
# Step 18 of 150
# Step 19 of 150
# Step 20 of 150
# Step 21 of 150
# Step 22 of 150
# Step 23 of 150
# Step 24 of 150
# Step 25 of 150
# Step 26 of 150
# Step 27 of 150
# Step 28 of 150
# Step 29 of 150
# Step 30 of 150
# Step 31 of 150
# Step 32 of 150
# Step 33 of 150
# Step 34 of 150
# Step 35 of 150
# Step 36 of 150
# Step 37 of 150
# Step 38 of 150
# Step 39 of 150
# Step 40 of 150
# Step 41 of 150
# Step 42 of 150
# Step 43 of 150
# Step 44 of 150
# Step 45 of 150
# Step 46 of 150

# %% [markdown]
# ## Plots

# %% [markdown]
# ### $\mathbb{Z_2}$ in $2D$

# %%
fig, ax = plt.subplots()
#ax.axvline(Tc, linestyle='--', color='k')
ax.plot(betas, energy,
        #marker='P', 
        #markeredgecolor='#1f1b93',
        #markersize=5., 
        color='C0',
        ls='-')
ax.set_ylabel(r"Avg. Plaquette Energy, $\langle E \rangle$", fontsize=16)
ax.set_xlabel(r"$\beta$", fontsize=16)
#ax.set_title(r"$3(\langle N_b^2 \rangle - \langle N_b \rangle^2)\, / 2L^2$ vs. T, L=32", fontsize=18)
ax.set_title(r"$\mathbb{Z}_2$ in $2D$", fontsize=18)
#ax.set_xlim(1.0, 3.5)
plt.grid('on')
#ax.legend(markerscale=1.5, fontsize=10)
#plt.show()
#plt.savefig('plots/Nb_plots/fluctuations/fluctuations_all_32.png', dpi=400, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">
